# %%
# Question 1 Answer:

# %%
"""
In Python, all built-in exceptions and user-defined exceptions are derived from the Exception class. 
This means that if we want to create a custom exception, it needs to inherit from the Exception class to have all the features and behaviors of a standard exception class.
By inheriting from the Exception class, our custom exception class can use all the methods and attributes defined in the Exception class, 
such as the __str__ method for converting the exception object to a string representation, the args attribute for accessing the error message, and the raise keyword for raising the exception.
Additionally, using the Exception class as the base class for our custom exception ensures that it will be recognized and handled correctly by the Python interpreter and other exception handling mechanisms.
For example, if we define a custom exception that does not inherit from the Exception class, it may not behave like a standard exception and may not be caught or handled by some parts of the code. 
Therefore, it is important to always inherit from the Exception class when creating a custom exception in Python.

"""

# %%
# Question 2 Answer:

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent, exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent+2)

print_exception_hierarchy(BaseException)
# Out:
#  BaseException
#    Exception
#      TypeError
#        FloatOperation
#        MultipartConversionError
#      StopAsyncIteration
#      StopIteration
#      ImportError
#        ModuleNotFoundError
#        ZipImportError
#      OSError
#        ConnectionError
#          BrokenPipeError
#          ConnectionAbortedError
#          ConnectionRefusedError
#          ConnectionResetError
#            RemoteDisconnected
#        BlockingIOError
#        ChildProcessError
#        FileExistsError
#        FileNotFoundError
#        IsADirectoryError
#        NotADirectoryError
#        InterruptedError
#          InterruptedSystemCall
#        PermissionError
#        ProcessLookupError
#        TimeoutError
#        UnsupportedOperation
#        itimer_error
#        herror
#        gaierror
#        SSLError
#          SSLCertVerificationError
#          SSLZeroReturnError
#          SSLWantWriteError
#          SSLWantReadError
#          SSLSyscallError
#          SSLEOFError
# ...

# %%
# Question 3 Answer:

# %%
"""
The ArithmeticError class in Python defines errors that occur during arithmetic operations. 
This class is a subclass of the Exception class and is itself the parent class of several specific arithmetic error classes.

The ArithmeticError class in Python defines errors that occur during arithmetic operations. 
This class is a subclass of the Exception class and is itself the parent class of several specific arithmetic error classes.
Here are two examples of errors that are defined in the ArithmeticError class:

ZeroDivisionError: This error occurs when we attempt to divide a number by zero. For example:

x = 10
y = 0
z = x / y   # ZeroDivisionError: division by zero


OverflowError: This error occurs when a calculation produces a number that is too large to be represented in the current data type.
For example:

x = 2 ** 1000
y = x ** x   # OverflowError: int too large to convert to float

In the first example, we are attempting to divide the number x by zero, which is not a valid arithmetic operation. 
This results in a ZeroDivisionError, which is a subclass of ArithmeticError.
In the second example, we are performing a calculation that produces a number that is too large to be represented in Python's standard int data type. 
This results in an OverflowError, which is also a subclass of ArithmeticError.
Both of these errors are specific cases of arithmetic errors and are defined as subclasses of the ArithmeticError class in Python. 
By catching the ArithmeticError class in an exception handler, we can handle all types of arithmetic errors in our program, 
regardless of the specific type of error that occurs.

"""

# %%
# Question 4 Answer:

# %%
"""
In Python, the LookupError class is a base class for several exception classes that are related to lookup errors. 
These errors occur when an item cannot be found in a collection or sequence. 
The LookupError class is useful because it allows us to catch and handle multiple types of lookup errors with a single except block.
Two common examples of exceptions that are derived from LookupError class are KeyError and IndexError.
1)KeyError: This error is raised when we try to access a non-existent key in a dictionary. 

For example, consider the following code:

>>> my_dict = {"apple": 1, "banana": 2, "orange": 3}
>>> print(my_dict["mango"])
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
KeyError: 'mango'


In this example, we are trying to access the value associated with the key "mango" in the my_dict dictionary. 
However, since "mango" is not a key in the dictionary, we get a KeyError.

2)IndexError: This error is raised when we try to access an element at an invalid index in a list, tuple or any other sequence. 

For example, consider the following code:

>>> my_list = [1, 2, 3]
>>> print(my_list[3])
Traceback (most recent call last):
  File "<stdin>", line 1, in <module>
IndexError: list index out of range

In this example, we are trying to access the element at index 3 in the my_list list. 
However, since my_list only contains 3 elements, we get an IndexError because we are trying to access an element at an invalid index.

"""

# %%
# Question 5 Answer:

# %%
"""

In Python, an ImportError is an error that occurs when the Python interpreter is unable to locate or import a module. 
This can happen for a variety of reasons, including:

1)The module is not installed: If the module is not installed on your system, 
you will need to install it before you can use it.

2)The module is not in the current working directory: If the module is not in the current working directory,
you will need to add its location to the sys.path variable.

3)The module name is misspelled or incorrect: If the module name is misspelled or incorrect, 
the interpreter will not be able to locate the module.

4)The module is not compatible with your version of Python: If the module was designed to work with a different version of Python than the one you are using, 
it may not be compatible.

5)There is a problem with the module itself: If the module is corrupted or has a syntax error, 
the interpreter may not be able to import it.

On the other hand, ModuleNotFoundError is a specific type of ImportError that occurs when the module being imported cannot be found. 
This error occurs when the interpreter is unable to locate the module in any of the directories specified in the sys.path variable. 
This can happen for the same reasons as the ImportError described above, but the specific error message will indicate that the module was not found.

"""

# %%
# Question 6 Answer:

# %%
"""

1)Catch specific exceptions: It is important to catch only the exceptions that you expect to be thrown. 
This will make your code more robust and easier to debug. Catching a broad exception such as "Exception" is generally not recommended.

2)Use multiple except blocks: When catching multiple exceptions, use multiple except blocks instead of a single block with multiple exceptions listed. 
This makes it easier to handle each exception differently.

3)Use finally block: Use the "finally" block to ensure that clean-up code is executed, regardless of whether an exception was thrown or not.

4)Log exceptions: Use logging to record exceptions and their stack traces. This will make it easier to debug your code and track down errors.

5)Raise exceptions sparingly: Only raise an exception when you need to signal an error or an exceptional condition. 
Avoid using exceptions for flow control.

6)Use custom exceptions: Define your own custom exceptions for specific error conditions that are specific to your code. 
This will make it easier to understand what went wrong and handle errors in a more meaningful way.

7)Keep error messages clear and concise: Use clear and concise error messages that accurately describe the problem. 
Avoid using jargon or technical terms that may confuse users.

8)Handle exceptions close to the source: Handle exceptions as close to the source of the error as possible. This will make it easier to debug and fix the problem.

Test error cases: Test your code with different error cases to make sure that it handles errors and exceptions correctly.

By following these best practices, you can write more robust and maintainable Python code that handles errors and exceptions gracefully.
